# %%
import matplotlib.pyplot as plt  #导入matplotlib库
import numpy as np  #导入numpy库
import pandas as pd  #导入pandas库

# %%
df = pd.read_csv('..//z_data//3_film.csv') #读取csv数据
df.head()  #展示前五行数据
# Out:
#    filmnum  filmsize  ratio  quality
# 0       45       106     17        6
# 1       44        99     15       18
# 2       61       149     27       10
# 3       41        97     27       16
# 4       54       148     30        8

# %%
X = df.iloc[:,1:4]  #选取data中的RM变量
y =df.filmnum  #设定target为y

# %%
from sklearn.model_selection import  train_test_split #导入数据划分包 
# 把X、y转化为数组形式，以便于计算
X = np.array(X.values)  
y = np.array(y.values) 
#以25%的数据构建测试样本，剩余作为训练样本
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state =1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-502fe8713d64> in <module>
# ----> 1 from sklearn.model_selection import  train_test_split #导入数据划分包
#       2 # 把X、y转化为数组形式，以便于计算
#       3 X = np.array(X.values)
#       4 y = np.array(y.values)
#       5 #以25%的数据构建测试样本，剩余作为训练样本
#
# D:\Program Files\anaconda3\lib\site-packages\sklearn\__init__.py in <module>
#      78     from . import _distributor_init  # noqa: F401
#      79     from . import __check_build  # noqa: F401
# ---> 80     from .base import clone
#      81     from .utils._show_versions import show_versions
#      82
#
# D:\Program Files\anaconda3\lib\site-packages\sklearn\base.py in <module>
#      19 from . import __version__
#      20 from ._config import get_config
# ---> 21 from .utils import _IS_32BIT
#      22 from .utils.validation import check_X_y
#      23 from .utils.validation import check_array
#
# D:\Program Files\anaconda3\lib\site-packages\sklearn\utils\__init__.py in <module>
#      21
#      22 from .murmurhash import murmurhash3_32
# ---> 23 from .class_weight import compute_class_weight, compute_sample_weight
#      24 from . import _joblib
#      25 from ..exceptions import DataConversionWarning
#
# D:\Program Files\anaconda3\lib\site-packages\sklearn\utils\class_weight.py in <module>
#       5 import numpy as np
#       6
# ----> 7 from .validation import _deprecate_positional_args
#       8
#       9
#
# D:\Program Files\anaconda3\lib\site-packages\sklearn\utils\validation.py in <module>
#      23 from contextlib import suppress
#      24
# ---> 25 from .fixes import _object_dtype_isnan, parse_version
#      26 from .. import get_config as _get_config
#      27 from ..exceptions import NonBLASDotWarning, PositiveSpectrumWarning
#
# D:\Program Files\anaconda3\lib\site-packages\sklearn\utils\fixes.py in <module>
#      16 import scipy.sparse as sp
#      17 import scipy
# ---> 18 import scipy.stats
#      19 from scipy.sparse.linalg import lsqr as sparse_lsqr  # noqa
#      20 from numpy.ma import MaskedArray as _MaskedArray  # TODO: remove in 0.25
#
# D:\Program Files\anaconda3\lib\site-packages\scipy\stats\__init__.py in <module>
#     389
#     390 """
# --> 391 from .stats import *
#     392 from .distributions import *
#     393 from .morestats import *
#
# D:\Program Files\anaconda3\lib\site-packages\scipy\stats\stats.py in <module>
#     172 from numpy import array, asarray, ma
#     173
# --> 174 from scipy.spatial.distance import cdist
#     175 from scipy.ndimage import measurements
#     176 from scipy._lib._util import (_lazywhere, check_random_state, MapWrapper,
#
# D:\Program Files\anaconda3\lib\site-packages\scipy\spatial\__init__.py in <module>
#     100 from ._plotutils import *
#     101 from ._procrustes import procrustes
# --> 102 from ._geometric_slerp import geometric_slerp
#     103
#     104 __all__ = [s for s in dir() if not s.startswith('_')]
#
# D:\Program Files\anaconda3\lib\site-packages\scipy\spatial\_geometric_slerp.py in <module>
#       6
#       7 import numpy as np
# ----> 8 from scipy.spatial.distance import euclidean
#       9
#      10
#
# D:\Program Files\anaconda3\lib\site-packages\scipy\spatial\distance.py in <module>
#     120 from . import _hausdorff
#     121 from ..linalg import norm
# --> 122 from ..special import rel_entr
#     123
#     124
#
# D:\Program Files\anaconda3\lib\site-packages\scipy\special\__init__.py in <module>
#     634 from ._ufuncs import *
#     635
# --> 636 from . import _basic
#     637 from ._basic import *
#     638
#
# D:\Program Files\anaconda3\lib\site-packages\scipy\special\_basic.py in <module>
#      15 from . import specfun
#      16 from . import orthogonal
# ---> 17 from ._comb import _comb_int
#      18
#      19
#
# ModuleNotFoundError: No module named 'scipy.special._comb'

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((94L, 3L), (32L, 3L), (94L,), (32L,))

# %%
from sklearn import linear_model  #导入linear_model库
ridge= linear_model.Ridge(alpha=0.1)  # 设置lambda值
ridge.fit(X_train,y_train) #使用训练数据进行参数求解
# Out:
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
print('求解截距项为：',ridge.intercept_)
print('求解系数为：',ridge.coef_)
# Out:
# 求解截距项为： 4.35314337580391
# 求解系数为： [ 0.37048481 -0.03831273  0.23046337]

# %%
y_hat = ridge.predict(X_test) #对测试集的预测
y_hat[0:9]  #打印前10个预测值
# Out:
# array([20.20853893, 74.31234956, 66.97821059, 50.6165136 , 50.53930114,
#        44.72765631, 57.00323469, 35.55225421, 58.49957742])

# %%
plt.figure(figsize=(10,6))  #设置图片尺寸
t = np.arange(len(X_test))  #创建t变量
#绘制y_test曲线
plt.plot(t, y_test, 'r', linewidth=2, label='y_test') 
#绘制y_test曲线
plt.plot(t, y_hat, 'g', linewidth=2, label='y_hat') 
plt.legend() #设置图例
plt.show()

# %%
from sklearn import metrics
from sklearn.metrics import r2_score
# 拟合优度R2的输出方法二
print("r2_score:",r2_score(y_test, y_hat)) 
# 用scikit-learn计算MAE
print("MAE:", metrics.mean_absolute_error(y_test, y_hat))
# 用scikit-learn计算MSE
print("MSE:", metrics.mean_squared_error(y_test, y_hat))
# # 用scikit-learn计算RMSE
print("RMSE:", np.sqrt(metrics.mean_squared_error(y_test, y_hat)))
# Out:
# r2_score: 0.8279400477123059
# MAE: 4.63126290238146
# MSE: 46.63832870779446
# RMSE: 6.829226069460174

# %%
from sklearn import linear_model  #导入linear_model库
lasso= linear_model.Lasso(alpha=0.1)  # 设置lambda值
lasso.fit(X_train,y_train) #使用训练数据进行参数求解
# Out:
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
print('求解截距项为：',lasso.intercept_)
print('求解系数为：',lasso.coef_)
# Out:
# 求解截距项为： 4.358584829813829
# 求解系数为： [ 0.36999035 -0.03494547  0.22750781]

# %%
y_hat_lasso = lasso.predict(X_test) #对测试集的预测
y_hat_lasso[0:9]  #打印前10个预测值
# Out:
# array([20.233949  , 74.32855715, 66.94661945, 50.62126153, 50.5335356 ,
#        44.75419636, 57.02133523, 35.56117031, 58.53426597])

# %%
plt.figure(figsize=(10,6))  #设置图片尺寸
t = np.arange(len(X_test))  #创建t变量
#绘制y_test曲线
plt.plot(t, y_test, 'r', linewidth=2, label='y_test') 
#绘制y_test曲线
plt.plot(t, y_hat_lasso, 'g', linewidth=2, label='y_hat_lasso') 
plt.legend() #设置图例
plt.show()

# %%
from sklearn import metrics
from sklearn.metrics import r2_score
# 拟合优度R2的输出方法二
print("r2_score:",r2_score(y_test, y_hat_lasso) )
# 用scikit-learn计算MAE
print("MAE:", metrics.mean_absolute_error(y_test, y_hat_lasso))
# 用scikit-learn计算MSE
print("MSE:", metrics.mean_squared_error(y_test, y_hat_lasso))
# # 用scikit-learn计算RMSE
print("RMSE:", np.sqrt(metrics.mean_squared_error(y_test, y_hat_lasso)))
# Out:
# r2_score: 0.8276541436150417
# MAE: 4.638494755480021
# MSE: 46.71582547034623
# RMSE: 6.834897619595061
