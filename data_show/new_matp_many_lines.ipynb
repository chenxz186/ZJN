# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.sans-serif"] = ["SimHei"]
plt.rcParams["axes.unicode_minus"] = False
  

def show_pnl_single1():
    df1 = pd.read_excel('IO趋势15M每周核算数据.xls')
    df1.index = pd.to_datetime(df1['交易日'], format='%Y-%m-%d')  # 字符串转换成日期格式
    print(df1)

    fig = plt.figure(figsize=(8, 6), dpi=200)  # dpi是提高分辨率的参数
    ax1 = fig.add_subplot(111)
    df1['逐笔累计盈亏'].plot(ax=ax1, grid=True, color='blue', label='IO趋势S')
    plt.xlabel('日期')
    ax1.set_ylabel('IO趋势S')
    plt.legend(loc=2)
    plt.title('IO趋势S')
    plt.show()
  

def show_pnl_single2():
    df2 = pd.read_excel('IO趋势60M每周核算数据.xls')
    df2.index = pd.to_datetime(df2['交易日'], format='%Y-%m-%d')  # 字符串转换成日期格式
    print(df2)

    fig = plt.figure(figsize=(8, 6), dpi=200)  # dpi是提高分辨率的参数
    ax1 = fig.add_subplot(111)
    df2['逐笔累计盈亏'].plot(ax=ax1, grid=True, color='orange', label='IO趋势L')
    plt.xlabel('日期')
    ax1.set_ylabel('IO趋势L')
    plt.legend(loc=2)
    plt.title('IO趋势L')
    plt.show()
  

def show_pnl_single3(): 
    df3 = pd.read_excel('IO趋势1D每周核算数据.xls')
    df3.index = pd.to_datetime(df3['交易日'], format='%Y-%m-%d')  # 字符串转换成日期格式
    df3['3倍逐笔累计盈亏'] = df3['逐笔累计盈亏'] * 3
    print(df3)

    fig = plt.figure(figsize=(8, 6), dpi=200)  # dpi是提高分辨率的参数
    ax1 = fig.add_subplot(111)
    df3['3倍逐笔累计盈亏'].plot(ax=ax1, grid=True, color='purple', label='IO趋势1D')
    plt.xlabel('日期')
    ax1.set_ylabel('IO趋势1D')
    plt.legend(loc=2)
    plt.title('IO趋势1D')
    plt.show()
  

def show_pnl_7():
    df1 = pd.read_excel('IO趋势15M每周核算数据.xls')
    df1.index = pd.to_datetime(df1['交易日'], format='%Y-%m-%d')  # 字符串转换成日期格式

    df2 = pd.read_excel('IO趋势60M每周核算数据.xls')
    df2.index = pd.to_datetime(df2['交易日'], format='%Y-%m-%d')  # 字符串转换成日期格式
    
    df3 = pd.read_excel('IO趋势1D每周核算数据.xls')
    df3.index = pd.to_datetime(df3['交易日'], format='%Y-%m-%d')  # 字符串转换成日期格式
    df3['3倍逐笔累计盈亏'] = df3['逐笔累计盈亏'] * 3
    df3['IO三策略合并'] = df1['逐笔累计盈亏'] + df2['逐笔累计盈亏'] + df3['3倍逐笔累计盈亏']
    print(df3['IO三策略合并'])

    fig = plt.figure(figsize=(8, 6), dpi=200)  # dpi是提高分辨率的参数
    ax1 = fig.add_subplot(111)
    df1['逐笔累计盈亏'].plot(ax=ax1, grid=True, color='blue', label='IO趋势S')
    df2['逐笔累计盈亏'].plot(ax=ax1, grid=True, color='orange', label='IO趋势L')
    df3['3倍逐笔累计盈亏'].plot(ax=ax1, grid=True, color='purple', label='IO趋势1D')
    df3['IO三策略合并'].plot(ax=ax1, grid=True, color='red', label='IO三策略盈亏合并')
    plt.xlabel('日期')
    ax1.set_ylabel('IO三策略')
    plt.legend(loc=2)
    plt.title('IO三策略盈亏对比')
    plt.show()


if __name__ == '__main__':
    show_pnl_single1()
    show_pnl_single2()
    show_pnl_single3()
    show_pnl_7()
# Out:
#                   交易日    涨跌  逐笔累计盈亏
# 交易日
# 2020-02-21 2020-02-21   0.0     0.0
# 2020-02-28 2020-02-28 -19.2   -19.2
# 2020-03-06 2020-03-06  -0.6   -19.8
# 2020-03-13 2020-03-13  20.8     1.0
# 2020-03-20 2020-03-20 -17.4   -16.4
# ...               ...   ...     ...
# 2022-04-01 2022-04-01  -5.8   995.3
# 2022-04-08 2022-04-08 -62.4   932.9
# 2022-04-15 2022-04-15   1.6   934.5
# 2022-04-22 2022-04-22 -26.0   908.5
# 2022-04-29 2022-04-29  17.4   925.9
#
# [115 rows x 3 columns]
#                   交易日     涨跌  逐笔累计盈亏
# 交易日
# 2020-02-21 2020-02-21    0.0     0.0
# 2020-02-28 2020-02-28  -16.7   -16.7
# 2020-03-06 2020-03-06    9.7    -7.0
# 2020-03-13 2020-03-13  183.0   176.0
# 2020-03-20 2020-03-20    0.0   176.0
# ...               ...    ...     ...
# 2022-04-01 2022-04-01    0.0  1548.2
# 2022-04-08 2022-04-08    0.0  1548.2
# 2022-04-15 2022-04-15    0.0  1548.2
# 2022-04-22 2022-04-22    0.0  1548.2
# 2022-04-29 2022-04-29    0.0  1548.2
#
# [115 rows x 3 columns]
#                   交易日    涨跌  逐笔累计盈亏  3倍逐笔累计盈亏
# 交易日
# 2020-02-21 2020-02-21   0.0     0.0       0.0
# 2020-02-28 2020-02-28   0.0     0.0       0.0
# 2020-03-06 2020-03-06   0.0     0.0       0.0
# 2020-03-13 2020-03-13   0.0     0.0       0.0
# 2020-03-20 2020-03-20  81.6    81.6     244.8
# ...               ...   ...     ...       ...
# 2022-04-01 2022-04-01   0.0  1121.6    3364.8
# 2022-04-08 2022-04-08   0.0  1121.6    3364.8
# 2022-04-15 2022-04-15   0.0  1121.6    3364.8
# 2022-04-22 2022-04-22   0.0  1121.6    3364.8
# 2022-04-29 2022-04-29   0.0  1121.6    3364.8
#
# [115 rows x 4 columns]
# 交易日
# 2020-02-21       0.0
# 2020-02-28     -35.9
# 2020-03-06     -26.8
# 2020-03-13     177.0
# 2020-03-20     404.4
#                ...
# 2022-04-01    5908.3
# 2022-04-08    5845.9
# 2022-04-15    5847.5
# 2022-04-22    5821.5
# 2022-04-29    5838.9
# Name: IO三策略合并, Length: 115, dtype: float64
