# %%
import easygui as g
import pyautogui as pg
import os
import time
import datetime


def statistics_time(func):
    """统计程序运行时间"""

    def test_time(*args, **kwargs):
        start_time = datetime.datetime.now()
        func(*args, **kwargs)
        end_time = datetime.datetime.now()
        result = end_time - start_time
        print('\n\n程序开始时间{}，\n结束时间{}，\n耗时{}'.format(start_time, end_time, result))

    return test_time


def run(x, y, contract, start_price, end_price, root_price):
    dir_path = 'F:\\杂物放置处\\商品期权'
    # 对T型报价图截取
    im = pg.screenshot()
    string = '{}-{}-7型报价图.jpg'.format(date, contract)
    filename = dir_path + '/' + string
    im.save(filename)
    print(string)
    time.sleep(1)
    # 对期货价进行截图
    pg.doubleClick(850, 60)
    time.sleep(1)
    im = pg.screenshot()
    string = '{}-{}.jpg'.format(date, contract)
    filename = dir_path + '/' + string
    im.save(filename)
    pg.keyDown('esc')
    pg.keyUp('esc')
    print(string)
    # 上面是对期货价进行截图

    commodity_type = contract.split(contract[-4:])[0]  # 获取商品代码，例如m2101提取后是m
    space_num = 0
    # 铝期权
    if commodity_type == 'al':
        if start_price <= 10000:
            space_num += (start_price - root_price) / 50
        elif 10000 < start_price <= 20000:
            if root_price <= 10000:
                space_num += (10000 - root_price) / 50 + (start_price - 10000) / 100
            elif 10000 < root_price <= start_price:
                space_num += (start_price - root_price) / 100
        elif start_price > 20000:
            if root_price <= 10000:
                space_num += (10000 - root_price) / 50 + (20000 - 10000) / 100 + (start_price - 20000) / 200
            elif 10000 < root_price <= 20000:
                space_num += (20000 - root_price) / 100 + (start_price - 20000) / 200
            elif 20000 < root_price <= start_price:
                space_num += (start_price - root_price) / 200
    # 铜期权
    if commodity_type == 'cu':
        if start_price <= 40000:
            space_num += (start_price - root_price) / 500
        elif 40000 < start_price <= 80000:
            if root_price <= 40000:
                space_num += (40000 - root_price) / 500 + (start_price - 40000) / 1000
            elif 40000 < root_price <= start_price:
                space_num += (start_price - root_price) / 1000
        elif start_price > 80000:
            if root_price <= 40000:
                space_num += (40000 - root_price) / 500 + (80000 - 40000) / 1000 + (start_price - 80000) / 2000
            elif 40000 < root_price <= 80000:
                space_num += (80000 - root_price) / 1000 + (start_price - 80000) / 2000
            elif 80000 < root_price <= start_price:
                space_num += (start_price - root_price) / 2000
    # 锌期权
    if commodity_type == 'zn':
        if start_price <= 10000:
            space_num += (start_price - root_price) / 100
        elif 10000 < start_price <= 25000:
            if root_price <= 10000:
                space_num += (10000 - root_price) / 100 + (start_price - 10000) / 200
            elif 10000 < root_price <= start_price:
                space_num += (start_price - root_price) / 200
        elif start_price > 25000:
            if root_price <= 10000:
                space_num += (10000 - root_price) / 100 + (25000 - 10000) / 200 + (start_price - 25000) / 500
            elif 10000 < root_price <= 25000:
                space_num += (25000 - root_price) / 200 + (start_price - 25000) / 500
            elif 25000 < root_price <= start_price:
                space_num += (start_price - root_price) / 500
    # 橡胶期权
    if commodity_type == 'ru':
        if start_price <= 10000:
            space_num += (start_price - root_price) / 100
        elif 10000 < start_price <= 25000:
            if root_price <= 10000:
                space_num += (10000 - root_price) / 100 + (start_price - 10000) / 250
            elif 10000 < root_price <= start_price:
                space_num += (start_price - root_price) / 250
        elif start_price > 25000:
            if root_price <= 10000:
                space_num += (10000 - root_price) / 100 + (25000 - 10000) / 250 + (start_price - 25000) / 500
            elif 10000 < root_price <= 25000:
                space_num += (25000 - root_price) / 250 + (start_price - 25000) / 500
            elif 25000 < root_price <= start_price:
                space_num += (start_price - root_price) / 500
    y = y + space_num * 22
    while True:
        # 截取认购
        pg.doubleClick(x, y)
        time.sleep(1)
        im = pg.screenshot()
        string = '{}-{}-C-{}.jpg'.format(date, contract, start_price)
        filename = dir_path + '/' + string
        im.save(filename)
        pg.keyDown('esc')
        pg.keyUp('esc')
        print(string)

        # 截取认沽
        pg.doubleClick(x + 1200, y)
        time.sleep(1)
        im = pg.screenshot()
        string = '{}-{}-P-{}.jpg'.format(date, contract, start_price)
        filename = dir_path + '/' + string
        im.save(filename)
        pg.keyDown('esc')
        pg.keyUp('esc')
        print(string)

        if start_price == end_price:
            break
        # 铝期权
        if commodity_type == 'al':
            if start_price <= 10000:
                start_price += 50
            elif 10000 < start_price <= 20000:
                start_price += 100
            elif start_price > 20000:
                start_price += 200
        # 铜期权
        if commodity_type == 'cu':
            if start_price <= 40000:
                start_price += 500
            elif 40000 < start_price <= 80000:
                start_price += 1000
            elif start_price > 80000:
                start_price += 2000
        # 锌期权
        if commodity_type == 'zn':
            if start_price <= 10000:
                start_price += 100
            elif 10000 < start_price <= 25000:
                start_price += 200
            elif start_price > 25000:
                start_price += 500
        # 橡胶期权
        if commodity_type == 'ru':
            if start_price <= 10000:
                start_price += 100
            elif 10000 < start_price <= 25000:
                start_price += 250
            elif start_price > 25000:
                start_price += 500
        y += 22


@statistics_time
def main():
    if 'al' in target:
        pg.click(400, 60)
        time.sleep(0.5)
        pg.click(430, 100)
        time.sleep(0.5)
        pg.click(430, 80)
        time.sleep(0.5)
        pg.click(400, 140)
        time.sleep(0.5)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        time.sleep(0.5)
        run(400, 100, 'al2101', 16200, 16800, 14400)
    if 'cu' in target:
        pg.click(400, 60)
        time.sleep(0.5)
        pg.click(430, 100)
        time.sleep(0.5)
        pg.click(430, 80)
        time.sleep(0.5)
        pg.click(400, 160)
        time.sleep(0.5)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        time.sleep(0.5)
        run(400, 100, 'cu2101', 58000, 60000, 34000)
    if 'zn' in target:
        pg.click(400, 60)
        time.sleep(0.5)
        pg.click(430, 100)
        time.sleep(0.5)
        pg.click(430, 80)
        time.sleep(0.5)
        pg.click(400, 170)
        time.sleep(0.5)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        time.sleep(0.5)
        run(400, 100, 'zn2101', 21600, 22400, 16200)
    if 'ru' in target:
        pg.click(400, 60)
        time.sleep(0.5)
        pg.click(430, 100)
        time.sleep(0.5)
        pg.click(430, 80)
        time.sleep(0.5)
        pg.click(400, 200)
        time.sleep(0.5)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        run(400, 100, 'ru2101', 14250, 15000, 9400)


date = g.enterbox('请输入日期，例如2020年7月20日，即输入20200720', '日期输入')
if date is None:
    exit()

target = [
    'al',
    'cu',
    'zn',
    'ru'
]
if __name__ == '__main__':
    main()
# Out:
# None-al2101-期权T图.jpg
# None-al2101.jpg
# None-al2101-C-16200.jpg
# None-al2101-P-16200.jpg
# None-al2101-C-16300.jpg
# None-al2101-P-16300.jpg
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-e02d92f96064> in <module>
#     229 ]
#     230 if __name__ == '__main__':
# --> 231     main()
#
# <ipython-input-1-e02d92f96064> in test_time(*args, **kwargs)
#      11     def test_time(*args, **kwargs):
#      12         start_time = datetime.datetime.now()
# ---> 13         func(*args, **kwargs)
#      14         end_time = datetime.datetime.now()
#      15         result = end_time - start_time
#
# <ipython-input-1-e02d92f96064> in main()
#     180         pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
#     181         time.sleep(0.5)
# --> 182         run(400, 100, 'al2101', 16200, 16800, 14400)
#     183     if 'cu' in target:
#     184         pg.click(400, 60)
#
# <ipython-input-1-e02d92f96064> in run(x, y, contract, start_price, end_price, root_price)
#     111         pg.doubleClick(x, y)
#     112         time.sleep(1)
# --> 113         im = pg.screenshot()
#     114         string = '{}-{}-C-{}.jpg'.format(date, contract, start_price)
#     115         filename = dir_path + '/' + string
#
# D:\Program Files (x86)\anaconda3\lib\site-packages\pyscreeze\__init__.py in wrapper(*args, **kwargs)
#     133         if _PILLOW_UNAVAILABLE:
#     134             raise PyScreezeException('The Pillow package is required to use this function.')
# --> 135         return wrappedFunction(*args, **kwargs)
#     136     return wrapper
#     137
#
# D:\Program Files (x86)\anaconda3\lib\site-packages\pyscreeze\__init__.py in _screenshot_win32(imageFilename, region)
#     425     # TODO - Use the winapi to get a screenshot, and compare performance with ImageGrab.grab()
#     426     # https://stackoverflow.com/a/3586280/1893164
# --> 427     im = ImageGrab.grab()
#     428     if region is not None:
#     429         assert len(region) == 4, 'region argument must be a tuple of four ints'
#
# D:\Program Files (x86)\anaconda3\lib\site-packages\PIL\ImageGrab.py in grab(bbox, include_layered_windows, all_screens)
#      38             im = im.crop(bbox)
#      39     else:
# ---> 40         offset, size, data = Image.core.grabscreen(include_layered_windows, all_screens)
#      41         im = Image.frombytes(
#      42             "RGB",
#
# OSError: screen grab failed
