# %%
import easygui as g
import pyautogui as pg
import os
import time
import datetime


class FuturesOption(object):
    @staticmethod
    def dce_option(extent):
        x, y = 400, 100
        contract, start_price, end_price, root_price = extent[0], extent[1], extent[2], extent[3]
        # 对T型报价图截取
        im = pg.screenshot()
        string = '{}-DCE_{}-7型报价图.jpg'.format(date, contract)
        filename = dir_path + '/' + string
        im.save(filename)
        print(string)
        time.sleep(1)
        # 对期货价进行截图
        pg.doubleClick(850, 60)
        time.sleep(1)
        im = pg.screenshot()
        string = '{}-DCE_{}.jpg'.format(date, contract)
        filename = dir_path + '/' + string
        im.save(filename)
        pg.keyDown('esc')
        pg.keyUp('esc')
        print(string)
        # 上面是对期货价进行截图

        commodity_type = contract.split(contract[-4:])[0]  # 获取商品代码，例如m2101提取后是m
        space_num = 0
        # 铁矿石
        if commodity_type == 'i':
            if start_price < 300:
                space_num += (start_price - root_price) / 5
            elif 300 <= start_price < 1000:
                if root_price < 300:
                    space_num += (300 - root_price) / 5 + (start_price - 300) / 10
                elif 300 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 10
            elif start_price >= 1000:
                if root_price < 300:
                    space_num += (300 - root_price) / 5 + (1000 - 300) / 10 + (start_price - 1000) / 20
                elif 300 <= root_price < 1000:
                    space_num += (1000 - root_price) / 10 + (start_price - 1000) / 20
                elif 1000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 20

        # 液化气
        if commodity_type == 'pg':
            if start_price < 2000:
                space_num += (start_price - root_price) / 25
            elif 2000 <= start_price < 6000:
                if root_price < 2000:
                    space_num += (2000 - root_price) / 25 + (start_price - 2000) / 50
                elif 2000 <= root_price < start_price:
                    space_num += (start_price - root_price) / 50
            elif start_price >= 6000:
                if root_price < 2000:
                    space_num += (2000 - root_price) / 25 + (6000 - 2000) / 50 + (start_price - 6000) / 100
                elif 2000 <= root_price < 6000:
                    space_num += (6000 - root_price) / 50 + (start_price - 6000) / 100
                elif 6000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 100

        # pp、pvc、塑料
        if commodity_type == 'pp' or commodity_type == 'v' or commodity_type == 'l':
            if start_price < 5000:
                space_num += (start_price - root_price) / 50
            elif 5000 <= start_price < 10000:
                if root_price < 5000:
                    space_num += (5000 - root_price) / 50 + (start_price - 5000) / 100
                elif 5000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 100
            elif start_price >= 10000:
                if root_price < 5000:
                    space_num += (5000 - root_price) / 50 + (10000 - 5000) / 100 + (start_price - 10000) / 200
                elif 5000 <= root_price < 10000:
                    space_num += (10000 - root_price) / 100 + (start_price - 10000) / 200
                elif 10000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 200
        y = y + space_num * 22
        while True:
            # 截取认购
            pg.doubleClick(x, y)
            time.sleep(1)
            im = pg.screenshot()
            string = '{}-DCE_{}-C-{}.jpg'.format(date, contract, start_price)
            print(string)
            filename = dir_path + '/' + string
            im.save(filename)
            pg.keyDown('esc')
            pg.keyUp('esc')

            # 截取认沽
            pg.doubleClick(x + 1200, y)
            time.sleep(1)
            im = pg.screenshot()
            string = '{}-DCE_{}-P-{}.jpg'.format(date, contract, start_price)
            print(string)
            filename = dir_path + '/' + string
            im.save(filename)
            pg.keyDown('esc')
            pg.keyUp('esc')

            if start_price == end_price:
                break
            # 铁矿石
            if commodity_type == 'i':
                if start_price < 300:
                    start_price += 5
                elif 300 <= start_price < 1000:
                    start_price += 10
                elif start_price >= 1000:
                    start_price += 20
            # 液化气
            if commodity_type == 'pg':
                if start_price < 2000:
                    start_price += 25
                elif 2000 <= start_price < 6000:
                    start_price += 50
                elif start_price >= 6000:
                    start_price += 100
            # pp, pvc, 塑料
            if commodity_type == 'pp' or commodity_type == 'v' or commodity_type == 'l':
                if start_price < 5000:
                    start_price += 50
                elif 5000 <= start_price < 10000:
                    start_price += 100
                elif start_price >= 10000:
                    start_price += 200
            y += 22

    @staticmethod
    def zce_option(extent):
        x, y = 400, 100
        contract, start_price, end_price, root_price = extent[0], extent[1], extent[2], extent[3]
        # 对T型报价图截取
        im = pg.screenshot()
        string = '{}-ZCE_{}-7型报价图.jpg'.format(date, contract)
        filename = dir_path + '/' + string
        im.save(filename)
        print(string)
        time.sleep(1)
        # 对期货价进行截图
        pg.doubleClick(850, 60)
        time.sleep(1)
        im = pg.screenshot()
        string = '{}-ZCE_{}.jpg'.format(date, contract)
        filename = dir_path + '/' + string
        im.save(filename)
        pg.keyDown('esc')
        pg.keyUp('esc')
        print(string)
        # 上面是对期货价进行截图

        commodity_type = contract.split(contract[-4:])[0]  # 获取商品代码，例如m2101提取后是m
        space_num = 0
        # 甲醇
        if commodity_type == 'ma' or commodity_type == 'rm':
            if start_price < 2500:
                space_num += (start_price - root_price) / 25
            elif 2500 <= start_price < 5000:
                if root_price < 2500:
                    space_num += (2500 - root_price) / 25 + (start_price - 2500) / 50
                elif 2500 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 50
            elif start_price >= 5000:
                if root_price < 2500:
                    space_num += (2500 - root_price) / 25 + (5000 - 2500) / 50 + (start_price - 5000) / 100
                elif 2500 <= root_price < 5000:
                    space_num += (5000 - root_price) / 50 + (start_price - 5000) / 100
                elif 5000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 100

        # 动力煤
        if commodity_type == 'zc':
            if start_price < 500:
                space_num += (start_price - root_price) / 5
            elif start_price >= 500:
                if root_price < 500:
                    space_num += (500 - root_price) / 5 + (start_price - 500) / 10
                elif 500 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 10

        # PTA
        if commodity_type == 'pta':
            if start_price < 5000:
                space_num += (start_price - root_price) / 50
            elif 5000 <= start_price < 10000:
                if root_price < 5000:
                    space_num += (5000 - root_price) / 50 + (start_price - 5000) / 100
                elif 5000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 100
            elif start_price >= 10000:
                if root_price < 5000:
                    space_num += (5000 - root_price) / 50 + (10000 - 5000) / 100 + (start_price - 10000) / 200
                elif 5000 <= root_price < 10000:
                    space_num += (10000 - root_price) / 100 + (start_price - 10000) / 200
                elif 10000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 200

        y = y + space_num * 22
        while True:
            # 截取认购
            pg.doubleClick(x, y)
            time.sleep(1)
            im = pg.screenshot()
            string = '{}-ZCE_{}-C-{}.jpg'.format(date, contract, start_price)
            print(string)
            filename = dir_path + '/' + string
            im.save(filename)
            pg.keyDown('esc')
            pg.keyUp('esc')

            # 截取认沽
            pg.doubleClick(x + 1200, y)
            time.sleep(1)
            im = pg.screenshot()
            string = '{}-ZCE_{}-P-{}.jpg'.format(date, contract, start_price)
            print(string)
            filename = dir_path + '/' + string
            im.save(filename)
            pg.keyDown('esc')
            pg.keyUp('esc')

            if start_price == end_price:
                break
            # 甲醇
            if commodity_type == 'ma' or commodity_type == 'rm':
                if start_price < 2500:
                    start_price += 25
                elif 2500 <= start_price < 5000:
                    start_price += 50
                elif start_price >= 5000:
                    start_price += 100

            # 动力煤
            if commodity_type == 'zc':
                if start_price < 500:
                    start_price += 5
                elif start_price >= 500:
                    start_price += 10

            # PTA
            if commodity_type == 'pta':
                if start_price < 5000:
                    start_price += 50
                elif 5000 <= start_price < 10000:
                    start_price += 100
                elif start_price >= 10000:
                    start_price += 200

            y += 22

    @staticmethod
    def shfe_option(extent):
        x, y = 400, 100
        contract, start_price, end_price, root_price = extent[0], extent[1], extent[2], extent[3]
        # 对T型报价图截取
        im = pg.screenshot()
        string = '{}-SHFE_{}-7型报价图.jpg'.format(date, contract)
        filename = dir_path + '/' + string
        im.save(filename)
        print(string)
        time.sleep(1)
        # 对期货价进行截图
        pg.doubleClick(850, 60)
        time.sleep(1)
        im = pg.screenshot()
        string = '{}-SHFE_{}.jpg'.format(date, contract)
        filename = dir_path + '/' + string
        im.save(filename)
        pg.keyDown('esc')
        pg.keyUp('esc')
        print(string)
        # 上面是对期货价进行截图

        commodity_type = contract.split(contract[-4:])[0]  # 获取商品代码，例如m2101提取后是m
        space_num = 0
        # 铝期权
        if commodity_type == 'al':
            if start_price < 10000:
                space_num += (start_price - root_price) / 50
            elif 10000 <= start_price < 20000:
                if root_price < 10000:
                    space_num += (10000 - root_price) / 50 + (start_price - 10000) / 100
                elif 10000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 100
            elif start_price >= 20000:
                if root_price < 10000:
                    space_num += (10000 - root_price) / 50 + (20000 - 10000) / 100 + (start_price - 20000) / 200
                elif 10000 <= root_price < 20000:
                    space_num += (20000 - root_price) / 100 + (start_price - 20000) / 200
                elif 20000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 200

        # 铜期权
        if commodity_type == 'cu':
            if start_price < 40000:
                space_num += (start_price - root_price) / 500
            elif 40000 <= start_price < 80000:
                if root_price < 40000:
                    space_num += (40000 - root_price) / 500 + (start_price - 40000) / 1000
                elif 40000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 1000
            elif start_price >= 80000:
                if root_price < 40000:
                    space_num += (40000 - root_price) / 500 + (80000 - 40000) / 1000 + (start_price - 80000) / 2000
                elif 40000 <= root_price < 80000:
                    space_num += (80000 - root_price) / 1000 + (start_price - 80000) / 2000
                elif 80000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 2000

        # 锌期权
        if commodity_type == 'zn':
            if start_price < 10000:
                space_num += (start_price - root_price) / 100
            elif 10000 <= start_price < 25000:
                if root_price < 10000:
                    space_num += (10000 - root_price) / 100 + (start_price - 10000) / 200
                elif 10000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 200
            elif start_price >= 25000:
                if root_price < 10000:
                    space_num += (10000 - root_price) / 100 + (25000 - 10000) / 200 + (start_price - 25000) / 500
                elif 10000 <= root_price < 25000:
                    space_num += (25000 - root_price) / 200 + (start_price - 25000) / 500
                elif 25000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 500

        # 橡胶期权
        if commodity_type == 'ru':
            if start_price < 10000:
                space_num += (start_price - root_price) / 100
            elif 10000 <= start_price < 25000:
                if root_price < 10000:
                    space_num += (10000 - root_price) / 100 + (start_price - 10000) / 250
                elif 10000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 250
            elif start_price >= 25000:
                if root_price < 10000:
                    space_num += (10000 - root_price) / 100 + (25000 - 10000) / 250 + (start_price - 25000) / 500
                elif 10000 <= root_price < 25000:
                    space_num += (25000 - root_price) / 250 + (start_price - 25000) / 500
                elif 25000 <= root_price <= start_price:
                    space_num += (start_price - root_price) / 500

        y = y + space_num * 22
        while True:
            # 截取认购
            pg.doubleClick(x, y)
            time.sleep(1)
            im = pg.screenshot()
            string = '{}-SHFE_{}-C-{}.jpg'.format(date, contract, start_price)
            print(string)
            filename = dir_path + '/' + string
            im.save(filename)
            pg.keyDown('esc')
            pg.keyUp('esc')

            # 截取认沽
            pg.doubleClick(x + 1200, y)
            time.sleep(1)
            im = pg.screenshot()
            string = '{}-SHFE_{}-P-{}.jpg'.format(date, contract, start_price)
            print(string)
            filename = dir_path + '/' + string
            im.save(filename)
            pg.keyDown('esc')
            pg.keyUp('esc')

            if start_price == end_price:
                break
            # 铝期权
            if commodity_type == 'al':
                if start_price < 10000:
                    start_price += 50
                elif 10000 <= start_price < 20000:
                    start_price += 100
                elif start_price >= 20000:
                    start_price += 200
            # 铜期权
            if commodity_type == 'cu':
                if start_price < 40000:
                    start_price += 500
                elif 40000 <= start_price < 80000:
                    start_price += 1000
                elif start_price >= 80000:
                    start_price += 2000
            # 锌期权
            if commodity_type == 'zn':
                if start_price < 10000:
                    start_price += 100
                elif 10000 <= start_price < 25000:
                    start_price += 200
                elif start_price >= 25000:
                    start_price += 500
            # 橡胶期权
            if commodity_type == 'ru':
                if start_price < 10000:
                    start_price += 100
                elif 10000 <= start_price < 25000:
                    start_price += 250
                elif start_price >= 25000:
                    start_price += 500
            y += 22


# 生成商品期权的对象
futures_option = FuturesOption()
dir_path = 'F:\\杂物放置处\\期货期权'
date = g.enterbox('请输入日期，例如2020年7月20日，即输入20200720', '日期输入')
if date is None:
    exit()


# ================================以上全是公共的代码=====================================


def dce_main():
    """大连商品交易所的期权品种"""
    if 'i' in dce_target:
        pg.click(400, 60)
        time.sleep(1)
        pg.click(430, 100)
        time.sleep(1)
        pg.click(430, 80)
        time.sleep(1)
        pg.click(400, 240)
        time.sleep(1)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        time.sleep(1)
        futures_option.dce_option(i_extent)
    if 'l' in dce_target:
        pg.click(400, 60)
        time.sleep(1)
        pg.click(430, 100)
        time.sleep(1)
        pg.click(430, 80)
        time.sleep(1)
        pg.click(400, 260)
        time.sleep(1)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        time.sleep(1)
        futures_option.dce_option(l_extent)
    if 'pg' in dce_target:
        pg.click(400, 60)
        time.sleep(1)
        pg.click(430, 200)
        time.sleep(1)
        pg.click(430, 260)
        time.sleep(1)
        pg.click(400, 100)
        time.sleep(1)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        futures_option.dce_option(pg_extent)
    if 'pp' in dce_target:
        pg.click(400, 60)
        time.sleep(1)
        pg.click(430, 200)
        time.sleep(1)
        pg.click(430, 260)
        time.sleep(1)
        pg.click(400, 120)
        time.sleep(1)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        futures_option.dce_option(pp_extent)
    if 'v' in dce_target:
        pg.click(400, 60)
        time.sleep(1)
        pg.click(430, 200)
        time.sleep(1)
        pg.click(430, 260)
        time.sleep(1)
        pg.click(400, 140)
        time.sleep(1)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        futures_option.dce_option(v_extent)


def zce_main():
    """郑州商品交易所的期权"""
    if 'ma' in zce_target:
        pg.click(400, 60)
        time.sleep(0.5)
        pg.click(430, 200)
        time.sleep(0.5)
        pg.click(430, 260)
        time.sleep(0.5)
        pg.click(400, 170)
        time.sleep(0.5)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        time.sleep(0.5)
        futures_option.zce_option(ma_extent)
    if 'zc' in zce_target:
        pg.click(400, 60)
        time.sleep(0.5)
        pg.click(430, 200)
        time.sleep(0.5)
        pg.click(430, 260)
        time.sleep(0.5)
        pg.click(400, 240)
        time.sleep(0.5)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        time.sleep(1)
        futures_option.zce_option(zc_extent)
    if 'pta' in zce_target:
        pg.click(400, 60)
        time.sleep(0.5)
        pg.click(430, 200)
        time.sleep(0.5)
        pg.click(430, 260)
        time.sleep(0.5)
        pg.click(400, 220)
        time.sleep(0.5)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        time.sleep(0.5)
        futures_option.zce_option(pta_extent)


def shfe_main():
    if 'al' in shfe_target:
        pg.click(400, 60)
        time.sleep(0.5)
        pg.click(430, 100)
        time.sleep(0.5)
        pg.click(430, 80)
        time.sleep(0.5)
        pg.click(400, 140)
        time.sleep(0.5)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        time.sleep(0.5)
        futures_option.shfe_option(al_extent)
    if 'cu' in shfe_target:
        pg.click(400, 60)
        time.sleep(0.5)
        pg.click(430, 100)
        time.sleep(0.5)
        pg.click(430, 80)
        time.sleep(0.5)
        pg.click(400, 160)
        time.sleep(0.5)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        time.sleep(0.5)
        futures_option.shfe_option(cu_extent)
    if 'zn' in shfe_target:
        pg.click(400, 60)
        time.sleep(0.5)
        pg.click(430, 100)
        time.sleep(0.5)
        pg.click(430, 80)
        time.sleep(0.5)
        pg.click(400, 170)
        time.sleep(0.5)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        time.sleep(0.5)
        futures_option.shfe_option(zn_extent)
    if 'ru' in shfe_target:
        pg.click(400, 60)
        time.sleep(0.5)
        pg.click(430, 100)
        time.sleep(0.5)
        pg.click(430, 80)
        time.sleep(0.5)
        pg.click(400, 200)
        time.sleep(0.5)
        pg.click(2525, 980)  # 有时T型报价图过长，出现滚动条，根据实际滚动向上向下，这里向下滚动。
        futures_option.shfe_option(ru_extent)


# ================================大连商品交易所的期权品种==========================================
dce_target = [
    'i',
    'l',
    'pg',
    'pp',
    'v'
]
dce_contract_month = '2102'
i_extent = [dce_target[0] + dce_contract_month, 950, 1260, 760]  # 第三与第四个参数是指截取的执行价范围，第五个参数是指参与的起始执行价
l_extent = [dce_target[1] + dce_contract_month, 6600, 8600, 5800]  # 第三与第四个参数是指截取的执行价范围，第五个参数是指参与的起始执行价
pg_extent = [dce_target[2] + dce_contract_month, 3500, 4500, 2750]  # 第三与第四个参数是指截取的执行价范围，第五个参数是指参与的起始执行价
pp_extent = [dce_target[3] + dce_contract_month, 7100, 9100, 6100]  # 第三与第四个参数是指截取的执行价范围，第五个参数是指参与的起始执行价
v_extent = [dce_target[4] + dce_contract_month, 6200, 8200, 5300]  # 第三与第四个参数是指截取的执行价范围，第五个参数是指参与的起始执行价

# ================================郑州商品交易所的期权品种==========================================
zce_target = [
    'ma',
    'zc',
    'pta',
]
zce_contract_month = '2102'
ma_extent = [zce_target[0] + zce_contract_month, 2300, 2900, 1825]  # 第三与第四个参数是指截取的执行价范围，第五个参数是指参与的起始执行价
zc_extent = [zce_target[1] + zce_contract_month, 670, 810, 510]  # 第三与第四个参数是指截取的执行价范围，第五个参数是指参与的起始执行价
pta_extent = [zce_target[2] + zce_contract_month, 3400, 4050, 3000]  # 第三与第四个参数是指截取的执行价范围，第五个参数是指参与的起始执行价

# ================================上海期货交易所的期权品种==========================================
shfe_target = [
    'al',
    'cu',
    'zn',
    'ru'
]
shfe_contract_month = '2102'
al_extent = [shfe_target[0] + shfe_contract_month, 14800, 16800, 14200]  # 第三与第四个参数是指截取的执行价范围，第五个参数是指参与的起始执行价
cu_extent = [shfe_target[1] + shfe_contract_month, 48000, 63000, 34000]  # 第三与第四个参数是指截取的执行价范围，第五个参数是指参与的起始执行价
zn_extent = [shfe_target[2] + shfe_contract_month, 18800, 24000, 17600]  # 第三与第四个参数是指截取的执行价范围，第五个参数是指参与的起始执行价
ru_extent = [shfe_target[3] + shfe_contract_month, 12000, 18250, 9300]  # 第三与第四个参数是指截取的执行价范围，第五个参数是指参与的起始执行价

if __name__ == '__main__':
    dce_main()
    zce_main()
    shfe_main()
# Out:
# 20201228-DCE_i2102-7型报价图.jpg
# 20201228-DCE_i2102.jpg
# 20201228-DCE_i2102-C-950.jpg
# 20201228-DCE_i2102-P-950.jpg
# 20201228-DCE_i2102-C-960.jpg
# 20201228-DCE_i2102-P-960.jpg
# 20201228-DCE_i2102-C-970.jpg
# 20201228-DCE_i2102-P-970.jpg
# 20201228-DCE_i2102-C-980.jpg
# 20201228-DCE_i2102-P-980.jpg
# 20201228-DCE_i2102-C-990.jpg
# 20201228-DCE_i2102-P-990.jpg
# 20201228-DCE_i2102-C-1000.jpg
# 20201228-DCE_i2102-P-1000.jpg
# 20201228-DCE_i2102-C-1020.jpg
# 20201228-DCE_i2102-P-1020.jpg
# 20201228-DCE_i2102-C-1040.jpg
# 20201228-DCE_i2102-P-1040.jpg
# 20201228-DCE_i2102-C-1060.jpg
# 20201228-DCE_i2102-P-1060.jpg
# 20201228-DCE_i2102-C-1080.jpg
# 20201228-DCE_i2102-P-1080.jpg
# 20201228-DCE_i2102-C-1100.jpg
# 20201228-DCE_i2102-P-1100.jpg
# 20201228-DCE_i2102-C-1120.jpg
# 20201228-DCE_i2102-P-1120.jpg
# 20201228-DCE_i2102-C-1140.jpg
# 20201228-DCE_i2102-P-1140.jpg
# 20201228-DCE_i2102-C-1160.jpg
# 20201228-DCE_i2102-P-1160.jpg
# 20201228-DCE_i2102-C-1180.jpg
# 20201228-DCE_i2102-P-1180.jpg
# 20201228-DCE_i2102-C-1200.jpg
# 20201228-DCE_i2102-P-1200.jpg
# 20201228-DCE_i2102-C-1220.jpg
# 20201228-DCE_i2102-P-1220.jpg
# 20201228-DCE_i2102-C-1240.jpg
# 20201228-DCE_i2102-P-1240.jpg
# 20201228-DCE_i2102-C-1260.jpg
# 20201228-DCE_i2102-P-1260.jpg
# 20201228-DCE_l2102-7型报价图.jpg
# 20201228-DCE_l2102.jpg
# 20201228-DCE_l2102-C-6600.jpg
# 20201228-DCE_l2102-P-6600.jpg
# 20201228-DCE_l2102-C-6700.jpg
# 20201228-DCE_l2102-P-6700.jpg
# 20201228-DCE_l2102-C-6800.jpg
# 20201228-DCE_l2102-P-6800.jpg
# 20201228-DCE_l2102-C-6900.jpg
# 20201228-DCE_l2102-P-6900.jpg
# 20201228-DCE_l2102-C-7000.jpg
# 20201228-DCE_l2102-P-7000.jpg
# 20201228-DCE_l2102-C-7100.jpg
# 20201228-DCE_l2102-P-7100.jpg
# 20201228-DCE_l2102-C-7200.jpg
# 20201228-DCE_l2102-P-7200.jpg
# 20201228-DCE_l2102-C-7300.jpg
# 20201228-DCE_l2102-P-7300.jpg
# 20201228-DCE_l2102-C-7400.jpg
# 20201228-DCE_l2102-P-7400.jpg
# 20201228-DCE_l2102-C-7500.jpg
# 20201228-DCE_l2102-P-7500.jpg
# 20201228-DCE_l2102-C-7600.jpg
# 20201228-DCE_l2102-P-7600.jpg
# 20201228-DCE_l2102-C-7700.jpg
# 20201228-DCE_l2102-P-7700.jpg
# 20201228-DCE_l2102-C-7800.jpg
# 20201228-DCE_l2102-P-7800.jpg
# 20201228-DCE_l2102-C-7900.jpg
# 20201228-DCE_l2102-P-7900.jpg
# 20201228-DCE_l2102-C-8000.jpg
# 20201228-DCE_l2102-P-8000.jpg
# 20201228-DCE_l2102-C-8100.jpg
# 20201228-DCE_l2102-P-8100.jpg
# 20201228-DCE_l2102-C-8200.jpg
# 20201228-DCE_l2102-P-8200.jpg
# 20201228-DCE_l2102-C-8300.jpg
# 20201228-DCE_l2102-P-8300.jpg
# 20201228-DCE_l2102-C-8400.jpg
# 20201228-DCE_l2102-P-8400.jpg
# 20201228-DCE_l2102-C-8500.jpg
# 20201228-DCE_l2102-P-8500.jpg
# 20201228-DCE_l2102-C-8600.jpg
# 20201228-DCE_l2102-P-8600.jpg
# 20201228-DCE_pg2102-7型报价图.jpg
# 20201228-DCE_pg2102.jpg
# 20201228-DCE_pg2102-C-3500.jpg
# 20201228-DCE_pg2102-P-3500.jpg
# 20201228-DCE_pg2102-C-3550.jpg
# 20201228-DCE_pg2102-P-3550.jpg
# 20201228-DCE_pg2102-C-3600.jpg
# 20201228-DCE_pg2102-P-3600.jpg
# 20201228-DCE_pg2102-C-3650.jpg
# 20201228-DCE_pg2102-P-3650.jpg
# 20201228-DCE_pg2102-C-3700.jpg
# 20201228-DCE_pg2102-P-3700.jpg
# 20201228-DCE_pg2102-C-3750.jpg
# 20201228-DCE_pg2102-P-3750.jpg
# 20201228-DCE_pg2102-C-3800.jpg
# 20201228-DCE_pg2102-P-3800.jpg
# 20201228-DCE_pg2102-C-3850.jpg
# 20201228-DCE_pg2102-P-3850.jpg
# 20201228-DCE_pg2102-C-3900.jpg
# 20201228-DCE_pg2102-P-3900.jpg
# 20201228-DCE_pg2102-C-3950.jpg
# 20201228-DCE_pg2102-P-3950.jpg
# 20201228-DCE_pg2102-C-4000.jpg
# 20201228-DCE_pg2102-P-4000.jpg
# 20201228-DCE_pg2102-C-4050.jpg
# 20201228-DCE_pg2102-P-4050.jpg
# 20201228-DCE_pg2102-C-4100.jpg
# 20201228-DCE_pg2102-P-4100.jpg
# 20201228-DCE_pg2102-C-4150.jpg
# 20201228-DCE_pg2102-P-4150.jpg
# 20201228-DCE_pg2102-C-4200.jpg
# 20201228-DCE_pg2102-P-4200.jpg
# 20201228-DCE_pg2102-C-4250.jpg
# 20201228-DCE_pg2102-P-4250.jpg
# 20201228-DCE_pg2102-C-4300.jpg
# 20201228-DCE_pg2102-P-4300.jpg
# 20201228-DCE_pg2102-C-4350.jpg
# 20201228-DCE_pg2102-P-4350.jpg
# 20201228-DCE_pg2102-C-4400.jpg
# 20201228-DCE_pg2102-P-4400.jpg
# 20201228-DCE_pg2102-C-4450.jpg
# 20201228-DCE_pg2102-P-4450.jpg
# 20201228-DCE_pg2102-C-4500.jpg
# 20201228-DCE_pg2102-P-4500.jpg
# 20201228-DCE_pp2102-7型报价图.jpg
# 20201228-DCE_pp2102.jpg
# 20201228-DCE_pp2102-C-7100.jpg
# 20201228-DCE_pp2102-P-7100.jpg
# 20201228-DCE_pp2102-C-7200.jpg
# 20201228-DCE_pp2102-P-7200.jpg
# 20201228-DCE_pp2102-C-7300.jpg
# 20201228-DCE_pp2102-P-7300.jpg
# 20201228-DCE_pp2102-C-7400.jpg
# 20201228-DCE_pp2102-P-7400.jpg
# 20201228-DCE_pp2102-C-7500.jpg
# 20201228-DCE_pp2102-P-7500.jpg
# 20201228-DCE_pp2102-C-7600.jpg
# 20201228-DCE_pp2102-P-7600.jpg
# 20201228-DCE_pp2102-C-7700.jpg
# 20201228-DCE_pp2102-P-7700.jpg
# 20201228-DCE_pp2102-C-7800.jpg
# 20201228-DCE_pp2102-P-7800.jpg
# 20201228-DCE_pp2102-C-7900.jpg
# 20201228-DCE_pp2102-P-7900.jpg
# 20201228-DCE_pp2102-C-8000.jpg
# 20201228-DCE_pp2102-P-8000.jpg
# 20201228-DCE_pp2102-C-8100.jpg
# 20201228-DCE_pp2102-P-8100.jpg
# 20201228-DCE_pp2102-C-8200.jpg
# 20201228-DCE_pp2102-P-8200.jpg
# 20201228-DCE_pp2102-C-8300.jpg
# 20201228-DCE_pp2102-P-8300.jpg
# 20201228-DCE_pp2102-C-8400.jpg
# 20201228-DCE_pp2102-P-8400.jpg
# 20201228-DCE_pp2102-C-8500.jpg
# 20201228-DCE_pp2102-P-8500.jpg
# 20201228-DCE_pp2102-C-8600.jpg
# 20201228-DCE_pp2102-P-8600.jpg
# 20201228-DCE_pp2102-C-8700.jpg
# 20201228-DCE_pp2102-P-8700.jpg
# 20201228-DCE_pp2102-C-8800.jpg
# 20201228-DCE_pp2102-P-8800.jpg
# 20201228-DCE_pp2102-C-8900.jpg
# 20201228-DCE_pp2102-P-8900.jpg
# 20201228-DCE_pp2102-C-9000.jpg
# 20201228-DCE_pp2102-P-9000.jpg
# 20201228-DCE_pp2102-C-9100.jpg
# 20201228-DCE_pp2102-P-9100.jpg
# 20201228-DCE_v2102-7型报价图.jpg
# 20201228-DCE_v2102.jpg
# 20201228-DCE_v2102-C-6200.jpg
# 20201228-DCE_v2102-P-6200.jpg
# 20201228-DCE_v2102-C-6300.jpg
# 20201228-DCE_v2102-P-6300.jpg
# 20201228-DCE_v2102-C-6400.jpg
# 20201228-DCE_v2102-P-6400.jpg
# 20201228-DCE_v2102-C-6500.jpg
# 20201228-DCE_v2102-P-6500.jpg
# 20201228-DCE_v2102-C-6600.jpg
# 20201228-DCE_v2102-P-6600.jpg
# 20201228-DCE_v2102-C-6700.jpg
# 20201228-DCE_v2102-P-6700.jpg
# 20201228-DCE_v2102-C-6800.jpg
# 20201228-DCE_v2102-P-6800.jpg
# 20201228-DCE_v2102-C-6900.jpg
# 20201228-DCE_v2102-P-6900.jpg
# 20201228-DCE_v2102-C-7000.jpg
# 20201228-DCE_v2102-P-7000.jpg
# 20201228-DCE_v2102-C-7100.jpg
# 20201228-DCE_v2102-P-7100.jpg
# 20201228-DCE_v2102-C-7200.jpg
# 20201228-DCE_v2102-P-7200.jpg
# 20201228-DCE_v2102-C-7300.jpg
# 20201228-DCE_v2102-P-7300.jpg
# 20201228-DCE_v2102-C-7400.jpg
# 20201228-DCE_v2102-P-7400.jpg
# 20201228-DCE_v2102-C-7500.jpg
# 20201228-DCE_v2102-P-7500.jpg
# 20201228-DCE_v2102-C-7600.jpg
# 20201228-DCE_v2102-P-7600.jpg
# 20201228-DCE_v2102-C-7700.jpg
# 20201228-DCE_v2102-P-7700.jpg
# 20201228-DCE_v2102-C-7800.jpg
# 20201228-DCE_v2102-P-7800.jpg
# 20201228-DCE_v2102-C-7900.jpg
# 20201228-DCE_v2102-P-7900.jpg
# 20201228-DCE_v2102-C-8000.jpg
# 20201228-DCE_v2102-P-8000.jpg
# 20201228-DCE_v2102-C-8100.jpg
# 20201228-DCE_v2102-P-8100.jpg
# 20201228-DCE_v2102-C-8200.jpg
# 20201228-DCE_v2102-P-8200.jpg
# 20201228-ZCE_ma2102-7型报价图.jpg
# 20201228-ZCE_ma2102.jpg
# 20201228-ZCE_ma2102-C-2300.jpg
# 20201228-ZCE_ma2102-P-2300.jpg
# 20201228-ZCE_ma2102-C-2325.jpg
# 20201228-ZCE_ma2102-P-2325.jpg
# 20201228-ZCE_ma2102-C-2350.jpg
# 20201228-ZCE_ma2102-P-2350.jpg
# 20201228-ZCE_ma2102-C-2375.jpg
# 20201228-ZCE_ma2102-P-2375.jpg
# 20201228-ZCE_ma2102-C-2400.jpg
# 20201228-ZCE_ma2102-P-2400.jpg
# 20201228-ZCE_ma2102-C-2425.jpg
# 20201228-ZCE_ma2102-P-2425.jpg
# 20201228-ZCE_ma2102-C-2450.jpg
# 20201228-ZCE_ma2102-P-2450.jpg
# 20201228-ZCE_ma2102-C-2475.jpg
# 20201228-ZCE_ma2102-P-2475.jpg
# 20201228-ZCE_ma2102-C-2500.jpg
# 20201228-ZCE_ma2102-P-2500.jpg
# 20201228-ZCE_ma2102-C-2550.jpg
# 20201228-ZCE_ma2102-P-2550.jpg
# 20201228-ZCE_ma2102-C-2600.jpg
# 20201228-ZCE_ma2102-P-2600.jpg
# 20201228-ZCE_ma2102-C-2650.jpg
# 20201228-ZCE_ma2102-P-2650.jpg
# 20201228-ZCE_ma2102-C-2700.jpg
# 20201228-ZCE_ma2102-P-2700.jpg
# 20201228-ZCE_ma2102-C-2750.jpg
# 20201228-ZCE_ma2102-P-2750.jpg
# 20201228-ZCE_ma2102-C-2800.jpg
# 20201228-ZCE_ma2102-P-2800.jpg
# 20201228-ZCE_ma2102-C-2850.jpg
# 20201228-ZCE_ma2102-P-2850.jpg
# 20201228-ZCE_ma2102-C-2900.jpg
# 20201228-ZCE_ma2102-P-2900.jpg
# 20201228-ZCE_zc2102-7型报价图.jpg
# 20201228-ZCE_zc2102.jpg
# 20201228-ZCE_zc2102-C-670.jpg
# 20201228-ZCE_zc2102-P-670.jpg
# 20201228-ZCE_zc2102-C-680.jpg
# 20201228-ZCE_zc2102-P-680.jpg
# 20201228-ZCE_zc2102-C-690.jpg
# 20201228-ZCE_zc2102-P-690.jpg
# 20201228-ZCE_zc2102-C-700.jpg
# 20201228-ZCE_zc2102-P-700.jpg
# 20201228-ZCE_zc2102-C-710.jpg
# 20201228-ZCE_zc2102-P-710.jpg
# 20201228-ZCE_zc2102-C-720.jpg
# 20201228-ZCE_zc2102-P-720.jpg
# 20201228-ZCE_zc2102-C-730.jpg
# 20201228-ZCE_zc2102-P-730.jpg
# 20201228-ZCE_zc2102-C-740.jpg
# 20201228-ZCE_zc2102-P-740.jpg
# 20201228-ZCE_zc2102-C-750.jpg
# 20201228-ZCE_zc2102-P-750.jpg
# 20201228-ZCE_zc2102-C-760.jpg
# 20201228-ZCE_zc2102-P-760.jpg
# 20201228-ZCE_zc2102-C-770.jpg
# 20201228-ZCE_zc2102-P-770.jpg
# 20201228-ZCE_zc2102-C-780.jpg
# 20201228-ZCE_zc2102-P-780.jpg
# 20201228-ZCE_zc2102-C-790.jpg
# 20201228-ZCE_zc2102-P-790.jpg
# 20201228-ZCE_zc2102-C-800.jpg
# 20201228-ZCE_zc2102-P-800.jpg
# 20201228-ZCE_zc2102-C-810.jpg
# 20201228-ZCE_zc2102-P-810.jpg
# 20201228-ZCE_pta2102-7型报价图.jpg
# 20201228-ZCE_pta2102.jpg
# 20201228-ZCE_pta2102-C-3400.jpg
# 20201228-ZCE_pta2102-P-3400.jpg
# 20201228-ZCE_pta2102-C-3450.jpg
# 20201228-ZCE_pta2102-P-3450.jpg
# 20201228-ZCE_pta2102-C-3500.jpg
# 20201228-ZCE_pta2102-P-3500.jpg
# 20201228-ZCE_pta2102-C-3550.jpg
# 20201228-ZCE_pta2102-P-3550.jpg
# 20201228-ZCE_pta2102-C-3600.jpg
# 20201228-ZCE_pta2102-P-3600.jpg
# 20201228-ZCE_pta2102-C-3650.jpg
# 20201228-ZCE_pta2102-P-3650.jpg
# 20201228-ZCE_pta2102-C-3700.jpg
# 20201228-ZCE_pta2102-P-3700.jpg
# 20201228-ZCE_pta2102-C-3750.jpg
# 20201228-ZCE_pta2102-P-3750.jpg
# 20201228-ZCE_pta2102-C-3800.jpg
# 20201228-ZCE_pta2102-P-3800.jpg
# 20201228-ZCE_pta2102-C-3850.jpg
# 20201228-ZCE_pta2102-P-3850.jpg
# 20201228-ZCE_pta2102-C-3900.jpg
# 20201228-ZCE_pta2102-P-3900.jpg
# 20201228-ZCE_pta2102-C-3950.jpg
# 20201228-ZCE_pta2102-P-3950.jpg
# 20201228-ZCE_pta2102-C-4000.jpg
# 20201228-ZCE_pta2102-P-4000.jpg
# 20201228-ZCE_pta2102-C-4050.jpg
# 20201228-ZCE_pta2102-P-4050.jpg
# 20201228-SHFE_al2102-7型报价图.jpg
# 20201228-SHFE_al2102.jpg
# 20201228-SHFE_al2102-C-14800.jpg
# 20201228-SHFE_al2102-P-14800.jpg
# 20201228-SHFE_al2102-C-14900.jpg
# 20201228-SHFE_al2102-P-14900.jpg
# 20201228-SHFE_al2102-C-15000.jpg
# 20201228-SHFE_al2102-P-15000.jpg
# 20201228-SHFE_al2102-C-15100.jpg
# 20201228-SHFE_al2102-P-15100.jpg
# 20201228-SHFE_al2102-C-15200.jpg
# 20201228-SHFE_al2102-P-15200.jpg
# 20201228-SHFE_al2102-C-15300.jpg
# 20201228-SHFE_al2102-P-15300.jpg
# 20201228-SHFE_al2102-C-15400.jpg
# 20201228-SHFE_al2102-P-15400.jpg
# 20201228-SHFE_al2102-C-15500.jpg
# 20201228-SHFE_al2102-P-15500.jpg
# 20201228-SHFE_al2102-C-15600.jpg
# 20201228-SHFE_al2102-P-15600.jpg
# 20201228-SHFE_al2102-C-15700.jpg
# 20201228-SHFE_al2102-P-15700.jpg
# 20201228-SHFE_al2102-C-15800.jpg
# 20201228-SHFE_al2102-P-15800.jpg
# 20201228-SHFE_al2102-C-15900.jpg
# 20201228-SHFE_al2102-P-15900.jpg
# 20201228-SHFE_al2102-C-16000.jpg
# 20201228-SHFE_al2102-P-16000.jpg
# 20201228-SHFE_al2102-C-16100.jpg
# 20201228-SHFE_al2102-P-16100.jpg
# 20201228-SHFE_al2102-C-16200.jpg
# 20201228-SHFE_al2102-P-16200.jpg
# 20201228-SHFE_al2102-C-16300.jpg
# 20201228-SHFE_al2102-P-16300.jpg
# 20201228-SHFE_al2102-C-16400.jpg
# 20201228-SHFE_al2102-P-16400.jpg
# 20201228-SHFE_al2102-C-16500.jpg
# 20201228-SHFE_al2102-P-16500.jpg
# 20201228-SHFE_al2102-C-16600.jpg
# 20201228-SHFE_al2102-P-16600.jpg
# 20201228-SHFE_al2102-C-16700.jpg
# 20201228-SHFE_al2102-P-16700.jpg
# 20201228-SHFE_al2102-C-16800.jpg
# 20201228-SHFE_al2102-P-16800.jpg
# 20201228-SHFE_cu2102-7型报价图.jpg
# 20201228-SHFE_cu2102.jpg
# 20201228-SHFE_cu2102-C-48000.jpg
# 20201228-SHFE_cu2102-P-48000.jpg
# 20201228-SHFE_cu2102-C-49000.jpg
# 20201228-SHFE_cu2102-P-49000.jpg
# 20201228-SHFE_cu2102-C-50000.jpg
# 20201228-SHFE_cu2102-P-50000.jpg
# 20201228-SHFE_cu2102-C-51000.jpg
# 20201228-SHFE_cu2102-P-51000.jpg
# 20201228-SHFE_cu2102-C-52000.jpg
# 20201228-SHFE_cu2102-P-52000.jpg
# 20201228-SHFE_cu2102-C-53000.jpg
# 20201228-SHFE_cu2102-P-53000.jpg
# 20201228-SHFE_cu2102-C-54000.jpg
# 20201228-SHFE_cu2102-P-54000.jpg
# 20201228-SHFE_cu2102-C-55000.jpg
# 20201228-SHFE_cu2102-P-55000.jpg
# 20201228-SHFE_cu2102-C-56000.jpg
# 20201228-SHFE_cu2102-P-56000.jpg
# 20201228-SHFE_cu2102-C-57000.jpg
# 20201228-SHFE_cu2102-P-57000.jpg
# 20201228-SHFE_cu2102-C-58000.jpg
# 20201228-SHFE_cu2102-P-58000.jpg
# 20201228-SHFE_cu2102-C-59000.jpg
# 20201228-SHFE_cu2102-P-59000.jpg
# 20201228-SHFE_cu2102-C-60000.jpg
# 20201228-SHFE_cu2102-P-60000.jpg
# 20201228-SHFE_cu2102-C-61000.jpg
# 20201228-SHFE_cu2102-P-61000.jpg
# 20201228-SHFE_cu2102-C-62000.jpg
# 20201228-SHFE_cu2102-P-62000.jpg
# 20201228-SHFE_cu2102-C-63000.jpg
# 20201228-SHFE_cu2102-P-63000.jpg
# 20201228-SHFE_zn2102-7型报价图.jpg
# 20201228-SHFE_zn2102.jpg
# 20201228-SHFE_zn2102-C-18800.jpg
# 20201228-SHFE_zn2102-P-18800.jpg
# 20201228-SHFE_zn2102-C-19000.jpg
# 20201228-SHFE_zn2102-P-19000.jpg
# 20201228-SHFE_zn2102-C-19200.jpg
# 20201228-SHFE_zn2102-P-19200.jpg
# 20201228-SHFE_zn2102-C-19400.jpg
# 20201228-SHFE_zn2102-P-19400.jpg
# 20201228-SHFE_zn2102-C-19600.jpg
# 20201228-SHFE_zn2102-P-19600.jpg
# 20201228-SHFE_zn2102-C-19800.jpg
# 20201228-SHFE_zn2102-P-19800.jpg
# 20201228-SHFE_zn2102-C-20000.jpg
# 20201228-SHFE_zn2102-P-20000.jpg
# 20201228-SHFE_zn2102-C-20200.jpg
# 20201228-SHFE_zn2102-P-20200.jpg
# 20201228-SHFE_zn2102-C-20400.jpg
# 20201228-SHFE_zn2102-P-20400.jpg
# 20201228-SHFE_zn2102-C-20600.jpg
# 20201228-SHFE_zn2102-P-20600.jpg
# 20201228-SHFE_zn2102-C-20800.jpg
# 20201228-SHFE_zn2102-P-20800.jpg
# 20201228-SHFE_zn2102-C-21000.jpg
# 20201228-SHFE_zn2102-P-21000.jpg
# 20201228-SHFE_zn2102-C-21200.jpg
# 20201228-SHFE_zn2102-P-21200.jpg
# 20201228-SHFE_zn2102-C-21400.jpg
# 20201228-SHFE_zn2102-P-21400.jpg
# 20201228-SHFE_zn2102-C-21600.jpg
# 20201228-SHFE_zn2102-P-21600.jpg
# 20201228-SHFE_zn2102-C-21800.jpg
# 20201228-SHFE_zn2102-P-21800.jpg
# 20201228-SHFE_zn2102-C-22000.jpg
# 20201228-SHFE_zn2102-P-22000.jpg
# 20201228-SHFE_zn2102-C-22200.jpg
# 20201228-SHFE_zn2102-P-22200.jpg
# 20201228-SHFE_zn2102-C-22400.jpg
# 20201228-SHFE_zn2102-P-22400.jpg
# 20201228-SHFE_zn2102-C-22600.jpg
# 20201228-SHFE_zn2102-P-22600.jpg
# 20201228-SHFE_zn2102-C-22800.jpg
# 20201228-SHFE_zn2102-P-22800.jpg
# 20201228-SHFE_zn2102-C-23000.jpg
# 20201228-SHFE_zn2102-P-23000.jpg
# 20201228-SHFE_zn2102-C-23200.jpg
# 20201228-SHFE_zn2102-P-23200.jpg
# 20201228-SHFE_zn2102-C-23400.jpg
# 20201228-SHFE_zn2102-P-23400.jpg
# 20201228-SHFE_zn2102-C-23600.jpg
# 20201228-SHFE_zn2102-P-23600.jpg
# 20201228-SHFE_zn2102-C-23800.jpg
# 20201228-SHFE_zn2102-P-23800.jpg
# 20201228-SHFE_zn2102-C-24000.jpg
# 20201228-SHFE_zn2102-P-24000.jpg
# 20201228-SHFE_ru2102-7型报价图.jpg
# 20201228-SHFE_ru2102.jpg
# 20201228-SHFE_ru2102-C-12000.jpg
# 20201228-SHFE_ru2102-P-12000.jpg
# 20201228-SHFE_ru2102-C-12250.jpg
# 20201228-SHFE_ru2102-P-12250.jpg
# 20201228-SHFE_ru2102-C-12500.jpg
# 20201228-SHFE_ru2102-P-12500.jpg
# 20201228-SHFE_ru2102-C-12750.jpg
# 20201228-SHFE_ru2102-P-12750.jpg
# 20201228-SHFE_ru2102-C-13000.jpg
# 20201228-SHFE_ru2102-P-13000.jpg
# 20201228-SHFE_ru2102-C-13250.jpg
# 20201228-SHFE_ru2102-P-13250.jpg
# 20201228-SHFE_ru2102-C-13500.jpg
# 20201228-SHFE_ru2102-P-13500.jpg
# 20201228-SHFE_ru2102-C-13750.jpg
# 20201228-SHFE_ru2102-P-13750.jpg
# 20201228-SHFE_ru2102-C-14000.jpg
# 20201228-SHFE_ru2102-P-14000.jpg
# 20201228-SHFE_ru2102-C-14250.jpg
# 20201228-SHFE_ru2102-P-14250.jpg
# 20201228-SHFE_ru2102-C-14500.jpg
# 20201228-SHFE_ru2102-P-14500.jpg
# 20201228-SHFE_ru2102-C-14750.jpg
# 20201228-SHFE_ru2102-P-14750.jpg
# 20201228-SHFE_ru2102-C-15000.jpg
# 20201228-SHFE_ru2102-P-15000.jpg
# 20201228-SHFE_ru2102-C-15250.jpg
# 20201228-SHFE_ru2102-P-15250.jpg
# 20201228-SHFE_ru2102-C-15500.jpg
# 20201228-SHFE_ru2102-P-15500.jpg
# 20201228-SHFE_ru2102-C-15750.jpg
# 20201228-SHFE_ru2102-P-15750.jpg
# 20201228-SHFE_ru2102-C-16000.jpg
# 20201228-SHFE_ru2102-P-16000.jpg
# 20201228-SHFE_ru2102-C-16250.jpg
# 20201228-SHFE_ru2102-P-16250.jpg
# 20201228-SHFE_ru2102-C-16500.jpg
# 20201228-SHFE_ru2102-P-16500.jpg
# 20201228-SHFE_ru2102-C-16750.jpg
# 20201228-SHFE_ru2102-P-16750.jpg
# 20201228-SHFE_ru2102-C-17000.jpg
# 20201228-SHFE_ru2102-P-17000.jpg
# 20201228-SHFE_ru2102-C-17250.jpg
# 20201228-SHFE_ru2102-P-17250.jpg
# 20201228-SHFE_ru2102-C-17500.jpg
# 20201228-SHFE_ru2102-P-17500.jpg
# 20201228-SHFE_ru2102-C-17750.jpg
# 20201228-SHFE_ru2102-P-17750.jpg
# 20201228-SHFE_ru2102-C-18000.jpg
# 20201228-SHFE_ru2102-P-18000.jpg
# 20201228-SHFE_ru2102-C-18250.jpg
# 20201228-SHFE_ru2102-P-18250.jpg
